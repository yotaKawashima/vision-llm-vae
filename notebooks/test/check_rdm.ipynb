# %%
## check rdm

import numpy as np
import matplotlib.pyplot as plt

# %%
# model RDM

model_rdm_path = "/workspace/data/model_activations/beta_vae_loss_llm_alignment_beta0.001_recon_loss_l2_llm_alignment_loss_cosine_similarity_gamma0.5/cocoDoerig/run_0/checkpoint_epoch30/input_image_layer_decoder.1.2_rdm_special515.npy"
model_rdm_path2 = "/workspace/data/model_activations/beta_vae_loss_llm_alignment_beta0.001_recon_loss_l2_llm_alignment_loss_cosine_similarity_gamma0.5/cocoDoerig/run_0/checkpoint_epoch30/input_image_layer_decoder.3.2_rdm_special515.npy"
#model_rdm = np.load(model_rdm_path)
model_rdm = np.load(model_rdm_path2)
plt.imshow(model_rdm)
plt.colorbar()
plt.title("Model RDM")
plt.show()

# show max and min value
print(f"Max value: {model_rdm.max()}")
print(f"Min value: {model_rdm.min()}")


# show elements with below 0 in imshow 
plt.imshow(model_rdm < 0, cmap="gray_r")
plt.colorbar()
plt.title("Model RDM (vmin=0)")
plt.show()
# Out:
# Max value: 0.9560546875
# Min value: -0.001953125
